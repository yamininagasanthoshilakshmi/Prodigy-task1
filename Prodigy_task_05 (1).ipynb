# %%
import pandas as pd
import numpy as np
import random

# Set a random seed for reproducibility
np.random.seed(42)

# Generate synthetic data
num_records = 500  # Number of accident records

# Date and Time (Randomly sampled from a specific range)
date_range = pd.date_range(start="2024-01-01", end="2024-12-31", freq="H")
dates = np.random.choice(date_range, num_records)

# Weather conditions
weather_conditions = ['Clear', 'Rain', 'Fog', 'Snow', 'Storm', 'Cloudy']
weather = np.random.choice(weather_conditions, num_records)

# Road conditions
road_conditions = ['Dry', 'Wet', 'Icy', 'Snowy', 'Under Construction']
road_condition = np.random.choice(road_conditions, num_records)

# Time of day
# Convert numpy.datetime64 to datetime objects before using strftime
time_of_day = [pd.to_datetime(date).strftime("%H:%M:%S") for date in dates]

# Accident severity
severity = np.random.choice([1, 2, 3, 4], num_records)

# Generate random locations (latitude and longitude)
latitudes = np.round(np.random.uniform(37.0, 39.0, num_records), 4)  # Latitude in some region
longitudes = np.round(np.random.uniform(-122.0, -120.0, num_records), 4)  # Longitude in some region

# Create DataFrame
accident_data = pd.DataFrame({
    'Date': [pd.to_datetime(date).strftime("%Y-%m-%d") for date in dates], # Convert to datetime objects
    'Time': time_of_day,
    'Weather': weather,
    'Road_Condition': road_condition,
    'Severity': severity,
    'Latitude': latitudes,
    'Longitude': longitudes
})

# Display first few rows
accident_data.head()
# Out:
# <ipython-input-1-39e30a8f5aee>:12: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   date_range = pd.date_range(start="2024-01-01", end="2024-12-31", freq="H")
#          Date      Time Weather      Road_Condition  Severity  Latitude  \
# 0  2024-10-29  22:00:00    Snow  Under Construction         2   38.1707
# 1  2024-02-05  20:00:00   Clear               Snowy         1   38.7365
# 2  2024-08-12  14:00:00   Clear  Under Construction         3   37.4117
# 3  2024-08-04  07:00:00   Storm               Snowy         3   37.2238
# 4  2024-08-26  22:00:00    Snow  Under Construction         3   37.5395
#
#    Longitude
# 0  -121.3461
# 1  -121.7022
# 2  -121.3888
# 3  -120.2467
# 4  -120.0073

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import random

# Set a random seed for reproducibility
np.random.seed(42)

# Generate synthetic data
num_records = 500  # Number of accident records

# Date and Time (Randomly sampled from a specific range)
date_range = pd.date_range(start="2024-01-01", end="2024-12-31", freq="H")
dates = np.random.choice(date_range, num_records)

# Weather conditions
weather_conditions = ['Clear', 'Rain', 'Fog', 'Snow', 'Storm', 'Cloudy']
weather = np.random.choice(weather_conditions, num_records)

# Road conditions
road_conditions = ['Dry', 'Wet', 'Icy', 'Snowy', 'Under Construction']
road_condition = np.random.choice(road_conditions, num_records)

# Time of day
# Convert numpy.datetime64 to datetime objects before using strftime
time_of_day = [pd.to_datetime(date).strftime("%H:%M:%S") for date in dates]

# Accident severity
severity = np.random.choice([1, 2, 3, 4], num_records)

# Generate random locations (latitude and longitude)
latitudes = np.round(np.random.uniform(37.0, 39.0, num_records), 4)  # Latitude in some region
longitudes = np.round(np.random.uniform(-122.0, -120.0, num_records), 4)  # Longitude in some region

# Create DataFrame
accident_data = pd.DataFrame({
    'Date': [pd.to_datetime(date).strftime("%Y-%m-%d") for date in dates], # Convert to datetime objects
    'Time': time_of_day,
    'Weather': weather,
    'Road_Condition': road_condition,
    'Severity': severity,
    'Latitude': latitudes,
    'Longitude': longitudes
})


# Now you can use accident_data in this cell
# Count plot of accidents by weather condition
plt.figure(figsize=(7,9 ))
sns.countplot(data=accident_data, x='Weather', palette='magma')
plt.title('Accidents by Weather Condition')
plt.xlabel('Weather Condition')
plt.ylabel('Number of Accidents')
plt.show()
# Out:
# <ipython-input-4-ec75281126b5>:14: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   date_range = pd.date_range(start="2024-01-01", end="2024-12-31", freq="H")
# <ipython-input-4-ec75281126b5>:51: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=accident_data, x='Weather', palette='magma')
